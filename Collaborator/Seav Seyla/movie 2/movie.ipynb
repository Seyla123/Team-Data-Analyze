# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
pwd = os.getcwd()
df = pd.read_csv(pwd + '/movies.csv')

# %%
df_modified = df.copy()

# %%
df_modified.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df_modified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
df_modified.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df_modified.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
df_modified['votes'].dropna(inplace=True)
df_modified.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df_modified.dropna(subset=["released","votes","score","writer","star","company","runtime","rating"],inplace=True)
df_modified.isnull().sum()
# Out:
# name           0
# rating         0
# genre          0
# year           0
# released       0
# score          0
# votes          0
# director       0
# writer         0
# star           0
# country        0
# budget      2101
# gross        162
# company        0
# runtime        0
# dtype: int64

# %%
df_modified.shape
# Out:
# (7574, 15)

# %%
df_modified['gross'].dropna(inplace=True)

# %%
df_modified
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7652                               The Eight Hundred  Not Rated     Action
# 7653                                      The Quarry          R      Crime
# 7656                                           Tulsa      PG-13     Comedy
# 7658                       Black Wall Street Burning          R      Drama
# 7659                                       I Am Fear  Not Rated     Horror
#
#       year                          released  score      votes  \
# ...

# %%
df_modified['budget'].fillna(df_modified['budget'].mean(), inplace=True)

# %%
df_modified.isnull().sum()
# Out:
# name          0
# rating        0
# genre         0
# year          0
# released      0
# score         0
# votes         0
# director      0
# writer        0
# star          0
# country       0
# budget        0
# gross       162
# company       0
# runtime       0
# dtype: int64

# %%
df_modified['gross'].fillna(df_modified['gross'].mean(), inplace=True)

# %%
df_modified.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
df_modified.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df_modified['votes'] = df_modified['votes'].astype('int64')
df_modified['budget'] = df_modified['budget'].astype('int64')
df_modified['gross'] = df_modified['gross'].astype('int64')

# %%
df_modified.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df_modified['released'].unique()
# Out:
# array(['June 13, 1980 (United States)', 'July 2, 1980 (United States)',
#        'June 20, 1980 (United States)', ..., 'April 17, 2020 (Mexico)',
#        'June 3, 2020 (United States)', 'March 3, 2020 (United States)'],
#       dtype=object)

# %%
df_modified[['releaseYear', 'releaseCountry']] = df_modified['released'].str.split('(', expand=True)

# %%
df_modified.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df_modified.drop(columns=['releaseCountry','released','year'],axis=1, inplace=True)

# %%
most_gross = df_modified.sort_values(by=['gross'], inplace=False , ascending=False)
most_gross
# Out:
#                                             name     rating   genre  score  \
# 5445                                      Avatar      PG-13  Action    7.8
# 7445                           Avengers: Endgame      PG-13  Action    8.4
# 3045                                     Titanic      PG-13   Drama    7.8
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action    7.8
# 7244                      Avengers: Infinity War      PG-13  Action    8.4
# ...                                          ...        ...     ...    ...
# 3394                                  I Want You          R   Crime    6.1
# 2906                                      Pusher  Not Rated   Crime    7.4
# 3818                        Love, Honor and Obey          R  Comedy    6.5
# 7580                         Run with the Hunted  Not Rated   Crime    5.2
# 3203                                  Trojan War      PG-13  Comedy    5.7
#
# ...

# %%
df_modified['releaseYear'] = df_modified['releaseYear'].str.strip(" ")

# %%
df_modified['releaseYear']
# Out:
# 0          June 13, 1980
# 1           July 2, 1980
# 2          June 20, 1980
# 3           July 2, 1980
# 4          July 25, 1980
#               ...
# 7652     August 28, 2020
# 7653      April 17, 2020
# 7656        June 3, 2020
# 7658    February 7, 2020
# 7659       March 3, 2020
# Name: releaseYear, Length: 7574, dtype: object

# %%
df_modified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7574 entries, 0 to 7659
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         7574 non-null   object
#  1   rating       7574 non-null   object
#  2   genre        7574 non-null   object
#  3   score        7574 non-null   float64
#  4   votes        7574 non-null   int64
#  5   director     7574 non-null   object
#  6   writer       7574 non-null   object
#  7   star         7574 non-null   object
#  8   country      7574 non-null   object
#  9   budget       7574 non-null   int64
#  10  gross        7574 non-null   int64
#  11  company      7574 non-null   object
#  12  runtime      7574 non-null   float64
#  13  releaseYear  7574 non-null   object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 1.1+ MB

# %%
pd.DataFrame(df_modified
            )
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7652                               The Eight Hundred  Not Rated     Action
# 7653                                      The Quarry          R      Crime
# 7656                                           Tulsa      PG-13     Comedy
# 7658                       Black Wall Street Burning          R      Drama
# 7659                                       I Am Fear  Not Rated     Horror
#
#       score    votes         director                   writer  \
# ...

# %%
df_modified['releaseYear'] = pd.to_datetime(df_modified['releaseYear'], format='%B %d, %Y', errors='coerce')
df_modified
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7652                               The Eight Hundred  Not Rated     Action
# 7653                                      The Quarry          R      Crime
# 7656                                           Tulsa      PG-13     Comedy
# 7658                       Black Wall Street Burning          R      Drama
# 7659                                       I Am Fear  Not Rated     Horror
#
#       score    votes         director                   writer  \
# ...

# %%
df_modified['yearCorrect'] = df_modified['releaseYear'].astype(str).str[:4]
df_modified
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7652                               The Eight Hundred  Not Rated     Action
# 7653                                      The Quarry          R      Crime
# 7656                                           Tulsa      PG-13     Comedy
# 7658                       Black Wall Street Burning          R      Drama
# 7659                                       I Am Fear  Not Rated     Horror
#
#       score    votes         director                   writer  \
# ...
