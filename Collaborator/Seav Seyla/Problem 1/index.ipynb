# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generate synthetic sales data
np.random.seed(42)
n_transactions = 1000
sales_data = {
    'Transaction ID': range(1, n_transactions + 1),
    'Date': pd.date_range(start='2023-01-01', periods=n_transactions),
    'Product Category': np.random.choice(['Electronics', 'Clothing', 'Books'], size=n_transactions),
    'Sales Amount': np.random.normal(loc=100, scale=20, size=n_transactions),
    'Customer Age': np.random.randint(20, 60, size=n_transactions),
    'Customer Gender': np.random.choice(['Male', 'Female'], size=n_transactions)
}
df = pd.DataFrame(sales_data)

# Explore the dataset
print(df.head())
print(df.info())
print(df.describe())
print(df['Product Category'].value_counts())

# Data cleaning and preparation (if necessary)
# No cleaning needed for this synthetic dataset

# Data visualization
# Distribution of Sales Amount
plt.figure(figsize=(10, 6))
sns.histplot(df['Sales Amount'], bins=30, kde=True)
plt.title('Distribution of Sales Amount')
plt.xlabel('Sales Amount')
plt.ylabel('Count')
plt.show()

# Sales trends over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='Sales Amount', data=df, estimator=sum, ci=None)
plt.title('Total Sales Amount Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales Amount')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Relationship between Customer Age and Sales Amount
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Customer Age', y='Sales Amount', data=df, hue='Customer Gender')
plt.title('Relationship between Customer Age and Sales Amount')
plt.xlabel('Customer Age')
plt.ylabel('Sales Amount')
plt.legend(title='Customer Gender')
plt.show()

# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()
# Out:
#    Transaction ID       Date Product Category  Sales Amount  Customer Age  \
# 0               1 2023-01-01            Books    100.970433            50
# 1               2 2023-01-02      Electronics     83.380998            55
# 2               3 2023-01-03            Books    105.409137            38
# 3               4 2023-01-04            Books     98.995238            55
# 4               5 2023-01-05      Electronics     95.221039            49
#
#   Customer Gender
# 0            Male
# 1            Male
# 2            Male
# 3            Male
# 4            Male
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   datetime64[ns]
#  2   Product Category  1000 non-null   object
#  3   Sales Amount      1000 non-null   float64
#  4   Customer Age      1000 non-null   int64
#  5   Customer Gender   1000 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 47.0+ KB
# None
#        Transaction ID                 Date  Sales Amount  Customer Age
# count     1000.000000                 1000   1000.000000   1000.000000
# mean       500.500000  2024-05-14 12:00:00    101.423667     39.846000
# min          1.000000  2023-01-01 00:00:00     42.074892     20.000000
# 25%        250.750000  2023-09-07 18:00:00     88.359399     30.000000
# 50%        500.500000  2024-05-14 12:00:00    101.241048     40.000000
# 75%        750.250000  2025-01-19 06:00:00    114.156822     50.000000
# max       1000.000000  2025-09-26 00:00:00    152.647641     59.000000
# std        288.819436                  NaN     19.834765     11.436393
# Product Category
# Electronics    355
# Clothing       326
# Books          319
# Name: count, dtype: int64
# /var/folders/bf/jskpgkr57cl65bh_6c8692140000gn/T/ipykernel_4437/3377181085.py:39: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Date', y='Sales Amount', data=df, estimator=sum, ci=None)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 58
#      56 # Correlation heatmap
#      57 plt.figure(figsize=(10, 8))
# ---> 58 sns.heatmap(df.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
#      59 plt.title('Correlation Heatmap')
#      60 plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Books'

# %%
df
# Out:
#      Transaction ID       Date Product Category  Sales Amount  Customer Age  \
# 0                 1 2023-01-01            Books    100.970433            50
# 1                 2 2023-01-02      Electronics     83.380998            55
# 2                 3 2023-01-03            Books    105.409137            38
# 3                 4 2023-01-04            Books     98.995238            55
# 4                 5 2023-01-05      Electronics     95.221039            49
# ..              ...        ...              ...           ...           ...
# 995             996 2025-09-22         Clothing     99.932511            27
# 996             997 2025-09-23         Clothing     96.596308            59
# 997             998 2025-09-24            Books     90.935439            23
# 998             999 2025-09-25            Books    113.927749            50
# 999            1000 2025-09-26      Electronics    119.106104            47
#
#     Customer Gender
# 0              Male
# 1              Male
# 2              Male
# 3              Male
# 4              Male
# ..              ...
# 995          Female
# 996            Male
# 997          Female
# 998            Male
# 999            Male
#
# [1000 rows x 6 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Hypothetical example - Generate synthetic currency data for illustration
currency_data = {
    'Denomination': ['$1', '$5', '$10', '$20', '$50', '$100'],
    'Year': [2019, 2020, 2021, 2019, 2020, 2021],
    'Production_Numbers': [1000000, 800000, 1200000, 500000, 600000, 900000],
    'Circulation_Figures': [900000, 700000, 1100000, 400000, 500000, 800000]
}
df = pd.DataFrame(currency_data)

# Explore the dataset
print(df.head())
print(df.info())
print(df.describe())

# Data visualization
# Trends in Production Numbers over Years
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='Production_Numbers', hue='Denomination', data=df)
plt.title('Trends in Currency Production Numbers')
plt.xlabel('Year')
plt.ylabel('Production Numbers')
plt.legend(title='Denomination')
plt.show()

# Distribution of Currency Denominations
plt.figure(figsize=(8, 6))
sns.barplot(x='Denomination', y='Production_Numbers', data=df, estimator=sum)
plt.title('Distribution of Currency Denominations by Production Numbers')
plt.xlabel('Denomination')
plt.ylabel('Total Production Numbers')
plt.show()

# Correlation between Production Numbers and Circulation Figures
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Production_Numbers', y='Circulation_Figures', data=df, hue='Denomination')
plt.title('Correlation between Production Numbers and Circulation Figures')
plt.xlabel('Production Numbers')
plt.ylabel('Circulation Figures')
plt.legend(title='Denomination')
plt.show()
# Out:
#   Denomination  Year  Production_Numbers  Circulation_Figures
# 0           $1  2019             1000000               900000
# 1           $5  2020              800000               700000
# 2          $10  2021             1200000              1100000
# 3          $20  2019              500000               400000
# 4          $50  2020              600000               500000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Denomination         6 non-null      object
#  1   Year                 6 non-null      int64
#  2   Production_Numbers   6 non-null      int64
#  3   Circulation_Figures  6 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 324.0+ bytes
# None
#               Year  Production_Numbers  Circulation_Figures
# count     6.000000        6.000000e+00         6.000000e+00
# mean   2020.000000        8.333333e+05         7.333333e+05
# std       0.894427        2.581989e+05         2.581989e+05
# min    2019.000000        5.000000e+05         4.000000e+05
# 25%    2019.250000        6.500000e+05         5.500000e+05
# 50%    2020.000000        8.500000e+05         7.500000e+05
# 75%    2020.750000        9.750000e+05         8.750000e+05
# max    2021.000000        1.200000e+06         1.100000e+06
